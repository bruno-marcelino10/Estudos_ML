# %% [markdown]
# # EDA Bancos

# %% [markdown]
# **TAREFA**:
#
# Plots, outliers, dados faltantes, tratamento

# %% [markdown]
# ### Importando Bibliotecas e Dados

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

dados = pd.read_excel("../data/bancos.xlsx", index_col = 0)
dados.head()
# Out:
#                IGP  CRED/PIB  DIV_LIQ       PIB    FIND11
# 2011-05-01  0.0043    0.4408   0.3784  366256.2 -0.014685
# 2011-06-01 -0.0018    0.4425   0.3773  370951.2  0.004013
# 2011-07-01 -0.0012    0.4436   0.3750  373143.3 -0.098772
# 2011-08-01  0.0044    0.4469   0.3699  376769.3 -0.014571
# 2011-09-01  0.0065    0.4530   0.3515  361724.6 -0.034073

# %% [markdown]
# ### Análise Exploratória dos Dados

# %% [markdown]
# ##### Análises Preliminares

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 111 entries, 2011-05-01 to 2021-04-01
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   IGP       111 non-null    float64
#  1   CRED/PIB  111 non-null    float64
#  2   DIV_LIQ   111 non-null    float64
#  3   PIB       111 non-null    float64
#  4   FIND11    111 non-null    float64
# dtypes: float64(5)
# memory usage: 5.2 KB

# %%
df.describe().T
# Out:
#           count           mean           std            min            25%  \
# IGP       111.0       0.618919      0.823682      -1.100000       0.170000
# CRED/PIB  111.0      48.851171      2.536499      44.080000      46.310000
# DIV_LIQ   111.0      43.043874     10.851833      30.710000      33.160000
# PIB       111.0  506114.468468  80689.086298  361724.600000  451610.500000
# FIND11    111.0       0.012020      0.079613      -0.331194      -0.039718
#
#                     50%            75%           max
# IGP            0.510000       0.905000       4.34000
# CRED/PIB      48.740000      50.785000      53.86000
# DIV_LIQ       37.900000      53.080000      66.39000
# PIB       508058.700000  559740.250000  735993.60000
# FIND11         0.012533       0.054469       0.26312

# %% [markdown]
# ##### Correlações

# %%
df.corr()['FIND11'].drop('FIND11').sort_values(ascending = False) # Correlação entre variáveis e target
# Out:
# DIV_LIQ     0.035980
# PIB         0.019035
# CRED/PIB   -0.013310
# IGP        -0.063316
# Name: FIND11, dtype: float64

# %%
sns.heatmap(df.corr(), cmap = "coolwarm", annot = True, linewidths = .6);

# %% [markdown]
# ### Séries Históricas

# %%
df.plot(subplots = True, figsize=(10,15))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>], dtype=object)

# %% [markdown]
# ##### Outliers

# %%
df.plot(kind = "box", subplots = True, figsize=(20,5))
# Out:
# IGP            AxesSubplot(0.125,0.125;0.133621x0.755)
# CRED/PIB    AxesSubplot(0.285345,0.125;0.133621x0.755)
# DIV_LIQ      AxesSubplot(0.44569,0.125;0.133621x0.755)
# PIB         AxesSubplot(0.606034,0.125;0.133621x0.755)
# FIND11      AxesSubplot(0.766379,0.125;0.133621x0.755)
# dtype: object

# %% [markdown]
# ##### Distribuição do Alvo

# %%
fig, ax = plt.subplots(figsize = (8,5))
df["FIND11"].plot(kind = "kde")
n, bins, patches = plt.hist(df["FIND11"], bins = 'auto', color = '#0504aa', alpha = 0.7, rwidth = 0.85)
plt.grid(axis = 'y', alpha = 0.75)
plt.xlabel('Valores de Y')
plt.ylabel('Frequência')
plt.title('Histograma de FIND11')
# Out:
# Text(0.5, 1.0, 'Histograma de FIND11')

# %% [markdown]
# ### Tratamento das Variáveis
